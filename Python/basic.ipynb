# %% [markdown]
# python is also know as dynamically type language
# about python and keywords
# variables , predefined words

# %%
print("Hello")
# Out:
# Hello

# %%
# Out:
# 139967803468272 139967803468208 139967803468400

# %%
#write a code to print lenght and writh of a rectangle
ln=input("Enter length of a rectangle")
print("The lenght is",(ln))
wridth = input ("Enter width of a rectangle")
print("The width is",(ln))
# Out:
# the lenght is  8
# The width is 8

# %%
#write a program which will take degree celsius in input and convert it into ferenaite
c = int(input("Enter the degree of celcius value"))
print("The Celsius is -:",(c))
f=(9/5*c)+32
print("The corresponding value of ferenaite is -:",(f))
# Out:
# Running cells with 'Python 3.14.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python -m pip install ipykernel -U --user --force-reinstall'

# %%
# write a proogram which will take radius as a input and print area of a circle 
r=float(input("Enter the radius -: "))
print("The radius is -: ",(r))
area = 3.14*r*2
print("The area of a circle is -: ",(area))
# Out:
# The radius is -: 2.0
# The area of a circle is -: 12.56

# %%
#Write a program which will check if the user can vote or not 
user = int(input("Your Age "))
print("The users Age is -:",(user))
if(user>=18):
    print("You can Vote ")
else:
    print("You Can not Vote ")
# Out:
# The users Age is -: 19
# You can Vote

# %%
#write a program to determine grade based on marks
mark1=int(input("Enter your marks1"))
mark2=int(input("Enter your marks2"))
mark3=int(input("Enter your marks3"))
if(mark1<33 & mark2<33 & mark3<33):
    print("You faild your exam")
elif mark1>33 and mark2>33 and mark3>33:
    print("you passed on exam ")

# %%
#write a program to determine grade based on marks
marks=int(input("Enter your grade"))
if marks<90 :  
  print("Your grade is A")
elif marks<80:
    print("Your grade is B") 
elif marks<70:
    print("Your grade is C")   
elif marks<60:
    print("Your grade is D")
# Out:
# Running cells with 'Python 3.14.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python -m pip install ipykernel -U --user --force-reinstall'

# %%
#Write a program to check where is number is divisible by 3 or 5
n=int(input("Enter the num"))
print("The no is",(n))
if n/3 and n/5:
    print("This number is Divisible by 3 and 5")
else :
    print("This no is not Divisible by 3 and 5")
# Out:
# The no is 15
# This number is Divisible by 3 and 5

# %%
#Write a program to find the larget of three numbers
num1=int(input("Enter first number"))
num2=int(input("Enter second number"))
num3=int(input("Enter third number"))

if num1>num2 and num1>num3 :
   print("The largest num is ",(num1))
elif num2>num1 and num2>num3:
   print("The largest num is ",(num2))
elif num3>num1 and num3>num2:
   print("The largest num is ",(num3))
else :
   print("All num is equal")
# Out:
# The largest num is  7

# %%
#write a program which is the given year is leap year or not
yr=int(input("Enter year to be checked"))
print("The year is",(yr))
if yr % 4 ==0 and yr % 100 !=0 or yr%400==0:
    print("The year is leap year")
else :
    print("The year is not leap year")
# Out:
# The year is 2001
# The year is not leap year

# %%
#Write a program to input electricity unit changes and calculate total electricity bill
#for first 10 unit rs 0.50/unit
#for next  50 units rs 0.75unit
unit=int(input("Enter electricity unit changes"))
if(unit<=50):
    Bill=unit*0.50
elif(unit<=150):
    Bill=(50*0.50)+(unit-50)*0.75
elif(unit<=250):
    Bill=(50*0.50)+(150*0.75)+(unit-150)
elif(unit>=450):
    Bill=(50*0.50)+(150*0.75)+(250*1.20)
#For sub charge
print("Your bill is",Bill)
sc=Bill*20/100+Bill
print("Your Total bill after subcharge is",sc)
# Out:
# Your bill is 105.0
# Your Total bill after subcharge is 126.0

# %%
#write a program to calculate the bill accordinglly to the kilometers
#

# %%
#either step is = 0 ya phir no perameter

# %%
def factorial(n):
    for i in range(1,1+n):
        if n%i==0:
            print(i end=" ")

factorial(5)

# %%
#write code to input 
def even_fact(n):
    pass
def odd_fact(n):
    pass
print(input("Enter the no."))
if n%2==0:
    print(even_fact(n))
else:
    print(odd_fact(n))

# %%
#write a code to input n and find ncr npr
def  factorial(n):
    if n == 0:
        return 1 
    else:
        return n*factorial(n -1)

# %%
list = [1,2,3,"Hello",5.7]
print(list)
for i in range(len(list)):
    print(list[i],end=" ")

# %%
#create empty list
lst=[]
lst=list()

print(lst)
print(list)

# %%
lst = [1,2,3,"Hello",5.7]
print(lst)

# %%
lst = eval(input ("Enter the list"))
print(lst)
print(type(lst))

# %%
# Write a program which of take integer as an iput in and increse all 
# even +5 ,odd -5
lst = eval (input("Enter a list"))
new_list = []

for i in lst:
    if i in 2 == 0 :
        new_list.append(i+5)
    else:
        new_list.append(i-5)

    print("New list",new_list)

# %%
lst=eval(input("Enter the  list"))
for i in range():
    if list[i]%2==0:
        list

# %%
# second largest
lst = eval(input("Enter the list "))

# %%
#write a code compute the diffeence between two lists
# data color1 =["red", "orange","green","blue","white"]
# color2 =["black","yello","green","blue"]

# color1-color2=["white"0,"orange","red"]
# color2-color1=["black",[yello]]

color1 =["red", "orange","green","blue","white"]
color2 =["black","yello","green","blue"]
lst1=[]
lst2=[]
for i in color1:
  if i not in color2:
    lst1.append(i)
    
for i in color2:
  if i in color1:
    lst2.append(i)

print(lst1)
print(lst2)
# Out:
# Running cells with 'Python 3.14.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python -m pip install ipykernel -U --user --force-reinstall'

# %%
# write a python program to pack consicutive duplicate of a given list of element into sublists 
# original list[0,0,1,2,3,4,4,5,6,6,7,8,9,4,4]
lst=[0,0,1,2,3,4,4,5,6,6,7,8,9,4,4]
lst1=[0]
for i in lst:
    # if i not in lst:
    if lst1[-1]!=1:
        lst1.append(i)
print(lst1)
# Out:
# Running cells with 'Python 3.14.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python -m pip install ipykernel -U --user --force-reinstall'

# %%
tpl= "Hello"
print(type(tpl))
# Out:
# Running cells with 'Python 3.14.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python -m pip install ipykernel -U --user --force-reinstall'
