// %%
#include <iostream>

int n = 5;
for (int i = 0; i < n ; i++)
{
    for (int j = 1; j <= n; j++)
    {
        std::cout << "* " ;
    }
    std::cout << std::endl;
}
// Out:
// * * * * *
// * * * * *
// * * * * *
// * * * * *
// * * * * *

// %%
// write a code to print triagular pattern
    int n = 4;
    for(int i = 0 ; i<n; i++){
        for(int j = 0 ; j<n ;j++){
            std::cout<<"* ";
        }
        std::cout<<std::endl;
    }
// Out:
// * * * *
// * * * *
// * * * *
// * * * *
