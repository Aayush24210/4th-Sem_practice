// %%
int n = 5;
for (int i = 0; i < n ; i++)
{
    for (int j = 1; j <= n; j++)
    {
        std::cout << "* " ;
    }

    std::cout << std::endl;
}
// Out:
// input_line_10:7:14: error: no member named 'cout' in namespace 'std'
//         std::cout << "* " ;
//         ~~~~~^
// input_line_10:9:10: error: no member named 'cout' in namespace 'std'
//     std::cout << std::endl;
//     ~~~~~^
// Interpreter Error:

// %%
// write a code to print triagular pattern
    int n = 4;
    for(int i = 0 ; i<n; i++){
        for(int j = 0 ; j<n ;j++){
            std::cout<<"* ";
        }
        std::cout<<std::endl;
    }
// Out:
// input_line_12:6:18: error: no member named 'cout' in namespace 'std'
//             std::cout<<"* ";
//             ~~~~~^
// input_line_12:8:14: error: no member named 'cout' in namespace 'std'
//         std::cout<<std::endl;
//         ~~~~~^
// Interpreter Error:
