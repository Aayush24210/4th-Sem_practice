# %%
int n = 5;
for (int i = 0; i < n ; i++)
{
    for (int j = 1; j <= n; j++)
    {
        std::cout << "* " ;
    }

    std::cout << std::endl;
}
# Out:
#   Cell In[1], line 1
#     int n = 5;
#         ^
# SyntaxError: invalid syntax
